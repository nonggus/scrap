# %%
import json
import requests
import pandas as pd
import os
import time

def get_cik_data():
    """
    ดึงข้อมูล CIK และ Ticker ของบริษัทต่างๆ จาก SEC
    """
    url = "https://www.sec.gov/files/company_tickers_exchange.json"
    # **สำคัญ:** เปลี่ยน YourAppName และ YourContactEmail@example.com เป็นข้อมูลของคุณ
    # การระบุ User-Agent ที่เหมาะสมเป็นสิ่งจำเป็นตามข้อกำหนดของ SEC EDGAR
    headers = {'User-Agent': 'AgentIdea (Contact: chanathip.thc@gmail.com)'}
    try:
        print("กำลังดึงข้อมูลบริษัทจาก SEC...")
        resp = requests.get(url, headers=headers)
        resp.raise_for_status() # ตรวจสอบว่า request สำเร็จหรือไม่
        data = resp.json()
        print("ดึงข้อมูลสำเร็จ กำลังประมวลผล...")

        fields = data.get('fields', [])
        try:
            # พยายามหา index ของ 'cik' หรือ 'cik_str'
            cik_index = fields.index('cik')
        except ValueError:
            try:
                cik_index = fields.index('cik_str')
            except ValueError:
                print("!!! ข้อผิดพลาด: ไม่พบฟิลด์ 'cik' หรือ 'cik_str' ในข้อมูล JSON จาก SEC")
                return None

        try:
            # พยายามหา index ของ 'ticker'
            ticker_index = fields.index('ticker')
        except ValueError:
            print("!!! คำเตือน: ไม่พบฟิลด์ 'ticker' ในข้อมูล JSON จาก SEC อาจทำให้ไม่สามารถดึงข้อมูลจาก FMP API ได้")
            ticker_index = -1 # ตั้งค่าเป็น -1 หากไม่พบคอลัมน์ ticker

        company_data = data.get('data', [])
        records = []
        processed_count = 0
        skipped_count = 0

        for item in company_data:
            cik = None
            ticker = None
            try:
                # ดึงและจัดรูปแบบ CIK ให้เป็น 10 หลัก
                if cik_index != -1 and len(item) > cik_index:
                    cik_raw = item[cik_index]
                    # แปลงเป็น int ก่อนเพื่อให้ zfill ทำงานกับตัวเลขได้ถูกต้อง แล้วค่อยแปลงกลับเป็น str
                    if isinstance(cik_raw, (int, str)) and str(cik_raw).isdigit():
                         cik = str(int(cik_raw)).zfill(10)
                    else:
                         # print(f"ข้ามรายการเนื่องจาก CIK ไม่ใช่ตัวเลข: {item}")
                         skipped_count += 1
                         continue


                # ดึง Ticker
                if ticker_index != -1 and len(item) > ticker_index:
                    ticker = item[ticker_index]

                # เพิ่มเฉพาะรายการที่มี Ticker (จำเป็นสำหรับ FMP API)
                # และ CIK ที่ถูกต้อง
                if cik and ticker:
                    records.append({'cik_str': cik, 'ticker': ticker})
                    processed_count += 1
                else:
                    # print(f"ข้ามรายการเนื่องจากไม่มี Ticker หรือ CIK: {item}")
                    skipped_count += 1


            except (TypeError, IndexError, ValueError) as e:
                 # print(f"ข้ามข้อมูลบางรายการเนื่องจากข้อผิดพลาดในการประมวลผล: {item} - {e}")
                 skipped_count += 1
                 continue # ข้ามรายการที่มีปัญหา

        print(f"ประมวลผลข้อมูลบริษัท: พบ {processed_count} รายการที่สมบูรณ์, ข้าม {skipped_count} รายการ")

        if not records:
            print("!!! ไม่พบข้อมูลบริษัทที่ถูกต้อง (มีทั้ง CIK และ Ticker)")
            return None

        df = pd.DataFrame(records)
        # ลบ Ticker ที่ซ้ำกัน อาจจะเก็บ CIK แรกที่เจอไว้ (ถ้าต้องการ)
        # df = df.drop_duplicates(subset=['ticker'], keep='first')
        # print(f"จำนวนบริษัทหลังจากลบ Ticker ซ้ำ: {len(df)}")
        return df.drop_duplicates(subset=['ticker'], keep='first') # คืนค่า DataFrame ที่ไม่มี Ticker ซ้ำ

    except requests.exceptions.RequestException as e:
        print(f"!!! เกิดข้อผิดพลาดในการดึงข้อมูล JSON จาก SEC: {e}")
        return None
    except Exception as e:
        print(f"!!! เกิดข้อผิดพลาดโดยรวมใน get_cik_data: {e}")
        return None

def download_financial_statements_api(ticker, cik, api_key):
    """
    ดาวน์โหลด financial statements (Annual) ผ่าน API ของ Financial Modeling Prep
    และบันทึกเป็นไฟล์ CSV
    """
    if not ticker:
        # โดยปกติ โค้ดส่วนหลักจะกรอง Ticker ที่เป็น None ออกไปแล้ว แต่ใส่ไว้เผื่อ
        print(f"ข้าม CIK: {cik} เนื่องจากไม่มี Ticker Symbol")
        return

    base_api_url = "https://financialmodelingprep.com/api/v3/"
    # รายการ statement ที่ต้องการดึงข้อมูล
    statements = {
        "Income_Statement": f"{base_api_url}income-statement/{ticker}",
        "Balance_Sheet": f"{base_api_url}balance-sheet-statement/{ticker}",
        "Cash_Flow_Statement": f"{base_api_url}cash-flow-statement/{ticker}"
    }
    output_folder = "downloaded_csvs_api" # ชื่อโฟลเดอร์สำหรับเก็บไฟล์ CSV
    os.makedirs(output_folder, exist_ok=True) # สร้างโฟลเดอร์ถ้ายังไม่มี

    # พารามิเตอร์สำหรับส่งไปกับ API request
    params = {
        "period": "annual",  # หรือ "quarterly" ถ้าต้องการรายไตรมาส
        "limit": 10,         # ดาวน์โหลดข้อมูลย้อนหลังกี่ปี (ปรับตามต้องการ)
        "apikey": api_key    # API Key ของคุณ
    }

    # **สำคัญ:** ระบุ User-Agent ใน Header ด้วย
    headers = {'User-Agent': 'AgentIdea (Contact: chanathip.thc@gmail.com)'}

    print(f"--- กำลังดึงข้อมูลสำหรับ Ticker: {ticker} (CIK: {cik}) ---")
    for name, url in statements.items():
        try:
            # ส่ง GET request ไปยัง API
            response = requests.get(url, params=params, headers=headers, timeout=30) # เพิ่ม timeout
            response.raise_for_status()  # เช็ค HTTP status code (ถ้าไม่ใช่ 2xx จะเกิด exception)

            data = response.json() # แปลง JSON response เป็น Python object

            # ตรวจสอบว่า API ส่งข้อมูลกลับมาเป็น list และมีข้อมูลข้างในหรือไม่
            if isinstance(data, list) and len(data) > 0:
                df = pd.DataFrame(data) # แปลง list of dictionaries เป็น DataFrame

                # --- (Optional) การปรับแต่ง DataFrame ก่อนบันทึก ---
                # เช่น เปลี่ยนชื่อคอลัมน์, เลือกเฉพาะคอลัมน์, จัดรูปแบบวันที่
                # df['date'] = pd.to_datetime(df['date'])
                # df = df.set_index('date')
                # ----------------------------------------------------

                # สร้างชื่อไฟล์: Ticker_StatementName_Period.csv
                filename = f"{ticker}_{name}_annual.csv"
                output_path = os.path.join(output_folder, filename)

                # บันทึก DataFrame เป็นไฟล์ CSV
                df.to_csv(output_path, index=False) # index=False คือไม่บันทึก index ของ DataFrame ลงในไฟล์
                print(f"  [สำเร็จ] บันทึก {name} -> {output_path}")

            # ตรวจสอบกรณี API ส่งข้อความ Error กลับมา (บาง API ทำแบบนี้)
            elif isinstance(data, dict) and 'Error Message' in data:
                 print(f"  [API Error] {name}: {data['Error Message']}")
            # กรณีอื่นๆ ที่ไม่ได้รับข้อมูลที่คาดหวัง
            else:
                print(f"  [ไม่พบข้อมูล] ไม่ได้รับข้อมูล {name} หรือรูปแบบไม่ถูกต้อง")
                # print(f"    Data received: {data}") # Uncomment เพื่อดูข้อมูลที่ได้รับจริง

            # หน่วงเวลาเล็กน้อยก่อนเรียก API ครั้งถัดไป ป้องกัน Rate Limit
            time.sleep(0.5) # ลดเวลาลงเล็กน้อย ถ้าไม่ติด Rate Limit

        except requests.exceptions.HTTPError as e:
            # จัดการข้อผิดพลาด HTTP เช่น 401 Unauthorized (API Key ผิด), 403 Forbidden, 404 Not Found, 429 Too Many Requests
             print(f"  [HTTP Error] {name} ({e.response.status_code}): {e}")
             try:
                 error_details = e.response.json()
                 print(f"    Details: {error_details}")
             except json.JSONDecodeError:
                 print(f"    Response Body: {e.response.text}")
             if e.response.status_code == 429:
                 print("    !!! อาจถึงขีดจำกัดการเรียก API (Rate Limit) กำลังรอสักครู่...")
                 time.sleep(10) # รอ 10 วินาทีถ้าเจอ Rate Limit
        except requests.exceptions.Timeout:
            print(f"  [Timeout Error] {name}: การร้องขอหมดเวลา")
            time.sleep(5) # รอสักครู่ก่อนลองใหม่ (ถ้ามีการวนซ้ำ)
        except requests.exceptions.RequestException as e:
            # ข้อผิดพลาดอื่นๆ เกี่ยวกับการเชื่อมต่อ/request
            print(f"  [Request Error] {name}: {e}")
        except Exception as e:
            # ข้อผิดพลาดอื่นๆ ที่ไม่คาดคิดระหว่างประมวลผล
            print(f"  [Unexpected Error] ในการประมวลผล {name}: {e}")
        # finally:
            # อาจจะใส่ time.sleep() ใน finally เพื่อให้มีการหน่วงเสมอ ไม่ว่าจะสำเร็จหรือ error
            # time.sleep(1)


# --- ส่วนหลักในการรันสคริปต์ ---
if __name__ == "__main__":
    # ==================================================
    #  !!! กรุณาใส่ API Key ของคุณที่นี่ !!!
    # ==================================================
    FMP_API_KEY = "TTBEw02NHIVS6EbcDiOOQd5rewsoQCoN"  # <--- แทนที่ด้วย API Key จริงจาก Financial Modeling Prep

    # ตรวจสอบว่าใส่ API Key หรือยัง
    if not FMP_API_KEY or FMP_API_KEY == "YOUR_ACTUAL_FMP_API_KEY_HERE":
        print("="*60)
        print("!!! คำเตือน: กรุณาใส่ API Key ของคุณในตัวแปร FMP_API_KEY")
        print("!!! คุณสามารถรับ API Key ได้จากเว็บไซต์ Financial Modeling Prep")
        print("="*60)
    else:
        # 1. ดึงข้อมูล CIK และ Ticker จาก SEC
        cik_df = get_cik_data()

        if cik_df is not None and not cik_df.empty:
            print("\nข้อมูล CIK และ Ticker ที่ดึงมา (ตัวอย่าง 5 รายการแรก):")
            print(cik_df.head())
            print(f"\nพบ Ticker Symbol ที่ไม่ซ้ำกันทั้งหมด {len(cik_df)} รายการ")

            print(f"\n===== เริ่มดาวน์โหลด Financial Statements ผ่าน API =====")
            print(f"จะดาวน์โหลดข้อมูลสำหรับ {len(cik_df)} บริษัท...")
            print(f"ไฟล์จะถูกบันทึกในโฟลเดอร์: '{os.path.abspath('downloaded_csvs_api')}'")


            # --- (Optional) เลือกดาวน์โหลดเฉพาะบางส่วนเพื่อทดสอบ ---
            # start_index = 0
            # end_index = 10 # ดาวน์โหลดแค่ 10 บริษัทแรก
            # cik_df_subset = cik_df.iloc[start_index:end_index]
            # print(f"\n!!! กำลังทดสอบดาวน์โหลดเฉพาะ {len(cik_df_subset)} บริษัทแรก !!!")
            # loop_target = cik_df_subset.iterrows()
            # ----------------------------------------------------

            loop_target = cik_df.iterrows() # ใช้ DataFrame ทั้งหมด

            # 2. วนลูปเพื่อดาวน์โหลดข้อมูลสำหรับแต่ละบริษัท
            total_companies = len(cik_df) # ใช้ len(cik_df_subset) ถ้าทดสอบ
            for index, row in loop_target:
                current_index = index + 1 # สำหรับแสดงลำดับ (ถ้าใช้ df ทั้งหมด)
                # ถ้าใช้ subset ต้องปรับ index เป็น index - start_index + 1
                # current_index = index - start_index + 1
                cik = row['cik_str']
                ticker = row['ticker']

                print(f"\n({current_index}/{total_companies}) บริษัท: {ticker} (CIK: {cik})")
                download_financial_statements_api(ticker, cik, FMP_API_KEY)

                # อาจเพิ่มการหน่วงเวลาระหว่างบริษัท หากเจอปัญหา Rate Limit บ่อยๆ
                # time.sleep(2) # รอ 2 วินาทีก่อนทำบริษัทถัดไป

            print("\n===== การดำเนินการดาวน์โหลด Financial Statements ผ่าน API เสร็จสิ้น =====")

        elif cik_df is not None and cik_df.empty:
             print("\nไม่พบข้อมูลบริษัทที่ถูกต้อง (มี CIK และ Ticker) หลังจากประมวลผลข้อมูลจาก SEC")
        else:
            # กรณี get_cik_data() คืนค่า None
            print("\n!!! ไม่สามารถดำเนินการต่อได้ เนื่องจากไม่สามารถดึงข้อมูล CIK และ Ticker ได้")
# Out:
# กำลังดึงข้อมูลบริษัทจาก SEC...
# ดึงข้อมูลสำเร็จ กำลังประมวลผล...
# ประมวลผลข้อมูลบริษัท: พบ 9691 รายการที่สมบูรณ์, ข้าม 0 รายการ
#
# ข้อมูล CIK และ Ticker ที่ดึงมา (ตัวอย่าง 5 รายการแรก):
#       cik_str ticker
# 0  0000320193   AAPL
# 1  0000789019   MSFT
# 2  0001045810   NVDA
# 3  0001652044  GOOGL
# 4  0001018724   AMZN
#
# พบ Ticker Symbol ที่ไม่ซ้ำกันทั้งหมด 9691 รายการ
#
# ===== เริ่มดาวน์โหลด Financial Statements ผ่าน API =====
# จะดาวน์โหลดข้อมูลสำหรับ 9691 บริษัท...
# ไฟล์จะถูกบันทึกในโฟลเดอร์: 'C:\Users\Gusju\Webscrap\downloaded_csvs_api'
#
# (1/9691) บริษัท: AAPL (CIK: 0000320193)
# --- กำลังดึงข้อมูลสำหรับ Ticker: AAPL (CIK: 0000320193) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\AAPL_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\AAPL_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\AAPL_Cash_Flow_Statement_annual.csv
#
# (2/9691) บริษัท: MSFT (CIK: 0000789019)
# --- กำลังดึงข้อมูลสำหรับ Ticker: MSFT (CIK: 0000789019) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\MSFT_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\MSFT_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\MSFT_Cash_Flow_Statement_annual.csv
#
# (3/9691) บริษัท: NVDA (CIK: 0001045810)
# --- กำลังดึงข้อมูลสำหรับ Ticker: NVDA (CIK: 0001045810) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\NVDA_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\NVDA_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\NVDA_Cash_Flow_Statement_annual.csv
#
# (4/9691) บริษัท: GOOGL (CIK: 0001652044)
# --- กำลังดึงข้อมูลสำหรับ Ticker: GOOGL (CIK: 0001652044) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\GOOGL_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\GOOGL_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\GOOGL_Cash_Flow_Statement_annual.csv
#
# (5/9691) บริษัท: AMZN (CIK: 0001018724)
# --- กำลังดึงข้อมูลสำหรับ Ticker: AMZN (CIK: 0001018724) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\AMZN_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\AMZN_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\AMZN_Cash_Flow_Statement_annual.csv
#
# (6/9691) บริษัท: META (CIK: 0001326801)
# --- กำลังดึงข้อมูลสำหรับ Ticker: META (CIK: 0001326801) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\META_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\META_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\META_Cash_Flow_Statement_annual.csv
#
# (7/9691) บริษัท: BRK-B (CIK: 0001067983)
# --- กำลังดึงข้อมูลสำหรับ Ticker: BRK-B (CIK: 0001067983) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\BRK-B_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\BRK-B_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\BRK-B_Cash_Flow_Statement_annual.csv
#
# (8/9691) บริษัท: AVGO (CIK: 0001730168)
# --- กำลังดึงข้อมูลสำหรับ Ticker: AVGO (CIK: 0001730168) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\AVGO_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\AVGO_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\AVGO_Cash_Flow_Statement_annual.csv
#
# (9/9691) บริษัท: TSLA (CIK: 0001318605)
# --- กำลังดึงข้อมูลสำหรับ Ticker: TSLA (CIK: 0001318605) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\TSLA_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\TSLA_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\TSLA_Cash_Flow_Statement_annual.csv
#
# (10/9691) บริษัท: TSM (CIK: 0001046179)
# --- กำลังดึงข้อมูลสำหรับ Ticker: TSM (CIK: 0001046179) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\TSM_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\TSM_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\TSM_Cash_Flow_Statement_annual.csv
#
# (11/9691) บริษัท: WMT (CIK: 0000104169)
# --- กำลังดึงข้อมูลสำหรับ Ticker: WMT (CIK: 0000104169) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\WMT_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\WMT_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\WMT_Cash_Flow_Statement_annual.csv
#
# (12/9691) บริษัท: LLY (CIK: 0000059478)
# --- กำลังดึงข้อมูลสำหรับ Ticker: LLY (CIK: 0000059478) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\LLY_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\LLY_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\LLY_Cash_Flow_Statement_annual.csv
#
# (13/9691) บริษัท: JPM (CIK: 0000019617)
# --- กำลังดึงข้อมูลสำหรับ Ticker: JPM (CIK: 0000019617) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\JPM_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\JPM_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\JPM_Cash_Flow_Statement_annual.csv
#
# (14/9691) บริษัท: V (CIK: 0001403161)
# --- กำลังดึงข้อมูลสำหรับ Ticker: V (CIK: 0001403161) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\V_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\V_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\V_Cash_Flow_Statement_annual.csv
#
# (15/9691) บริษัท: MA (CIK: 0001141391)
# --- กำลังดึงข้อมูลสำหรับ Ticker: MA (CIK: 0001141391) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\MA_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\MA_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\MA_Cash_Flow_Statement_annual.csv
#
# (16/9691) บริษัท: SPY (CIK: 0000884394)
# --- กำลังดึงข้อมูลสำหรับ Ticker: SPY (CIK: 0000884394) ---
#   [ไม่พบข้อมูล] ไม่ได้รับข้อมูล Income_Statement หรือรูปแบบไม่ถูกต้อง
#   [ไม่พบข้อมูล] ไม่ได้รับข้อมูล Balance_Sheet หรือรูปแบบไม่ถูกต้อง
#   [ไม่พบข้อมูล] ไม่ได้รับข้อมูล Cash_Flow_Statement หรือรูปแบบไม่ถูกต้อง
#
# (17/9691) บริษัท: XOM (CIK: 0000034088)
# --- กำลังดึงข้อมูลสำหรับ Ticker: XOM (CIK: 0000034088) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\XOM_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\XOM_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\XOM_Cash_Flow_Statement_annual.csv
#
# (18/9691) บริษัท: COST (CIK: 0000909832)
# --- กำลังดึงข้อมูลสำหรับ Ticker: COST (CIK: 0000909832) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\COST_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\COST_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\COST_Cash_Flow_Statement_annual.csv
#
# (19/9691) บริษัท: NFLX (CIK: 0001065280)
# --- กำลังดึงข้อมูลสำหรับ Ticker: NFLX (CIK: 0001065280) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\NFLX_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\NFLX_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\NFLX_Cash_Flow_Statement_annual.csv
#
# (20/9691) บริษัท: UNH (CIK: 0000731766)
# --- กำลังดึงข้อมูลสำหรับ Ticker: UNH (CIK: 0000731766) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\UNH_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\UNH_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\UNH_Cash_Flow_Statement_annual.csv
#
# (21/9691) บริษัท: PG (CIK: 0000080424)
# --- กำลังดึงข้อมูลสำหรับ Ticker: PG (CIK: 0000080424) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\PG_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\PG_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\PG_Cash_Flow_Statement_annual.csv
#
# (22/9691) บริษัท: JNJ (CIK: 0000200406)
# --- กำลังดึงข้อมูลสำหรับ Ticker: JNJ (CIK: 0000200406) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\JNJ_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\JNJ_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\JNJ_Cash_Flow_Statement_annual.csv
#
# (23/9691) บริษัท: ORCL (CIK: 0001341439)
# --- กำลังดึงข้อมูลสำหรับ Ticker: ORCL (CIK: 0001341439) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\ORCL_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\ORCL_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\ORCL_Cash_Flow_Statement_annual.csv
#
# (24/9691) บริษัท: HD (CIK: 0000354950)
# --- กำลังดึงข้อมูลสำหรับ Ticker: HD (CIK: 0000354950) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\HD_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\HD_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\HD_Cash_Flow_Statement_annual.csv
#
# (25/9691) บริษัท: KO (CIK: 0000021344)
# --- กำลังดึงข้อมูลสำหรับ Ticker: KO (CIK: 0000021344) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\KO_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\KO_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\KO_Cash_Flow_Statement_annual.csv
#
# (26/9691) บริษัท: ABBV (CIK: 0001551152)
# --- กำลังดึงข้อมูลสำหรับ Ticker: ABBV (CIK: 0001551152) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\ABBV_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\ABBV_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\ABBV_Cash_Flow_Statement_annual.csv
#
# (27/9691) บริษัท: SAP (CIK: 0001000184)
# --- กำลังดึงข้อมูลสำหรับ Ticker: SAP (CIK: 0001000184) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\SAP_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\SAP_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\SAP_Cash_Flow_Statement_annual.csv
#
# (28/9691) บริษัท: TMUS (CIK: 0001283699)
# --- กำลังดึงข้อมูลสำหรับ Ticker: TMUS (CIK: 0001283699) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\TMUS_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\TMUS_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\TMUS_Cash_Flow_Statement_annual.csv
#
# (29/9691) บริษัท: BAC (CIK: 0000070858)
# --- กำลังดึงข้อมูลสำหรับ Ticker: BAC (CIK: 0000070858) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\BAC_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\BAC_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\BAC_Cash_Flow_Statement_annual.csv
#
# (30/9691) บริษัท: NVO (CIK: 0000353278)
# --- กำลังดึงข้อมูลสำหรับ Ticker: NVO (CIK: 0000353278) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\NVO_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\NVO_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\NVO_Cash_Flow_Statement_annual.csv
#
# (31/9691) บริษัท: BABA (CIK: 0001577552)
# --- กำลังดึงข้อมูลสำหรับ Ticker: BABA (CIK: 0001577552) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\BABA_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\BABA_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\BABA_Cash_Flow_Statement_annual.csv
#
# (32/9691) บริษัท: RCIT (CIK: 0002008670)
# --- กำลังดึงข้อมูลสำหรับ Ticker: RCIT (CIK: 0002008670) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\RCIT_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\RCIT_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\RCIT_Cash_Flow_Statement_annual.csv
#
# (33/9691) บริษัท: ASML (CIK: 0000937966)
# --- กำลังดึงข้อมูลสำหรับ Ticker: ASML (CIK: 0000937966) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\ASML_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\ASML_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\ASML_Cash_Flow_Statement_annual.csv
#
# (34/9691) บริษัท: PM (CIK: 0001413329)
# --- กำลังดึงข้อมูลสำหรับ Ticker: PM (CIK: 0001413329) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\PM_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\PM_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\PM_Cash_Flow_Statement_annual.csv
#
# (35/9691) บริษัท: CVX (CIK: 0000093410)
# --- กำลังดึงข้อมูลสำหรับ Ticker: CVX (CIK: 0000093410) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\CVX_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\CVX_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\CVX_Cash_Flow_Statement_annual.csv
#
# (36/9691) บริษัท: CRM (CIK: 0001108524)
# --- กำลังดึงข้อมูลสำหรับ Ticker: CRM (CIK: 0001108524) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\CRM_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\CRM_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\CRM_Cash_Flow_Statement_annual.csv
#
# (37/9691) บริษัท: TM (CIK: 0001094517)
# --- กำลังดึงข้อมูลสำหรับ Ticker: TM (CIK: 0001094517) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\TM_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\TM_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\TM_Cash_Flow_Statement_annual.csv
#
# (38/9691) บริษัท: ABT (CIK: 0000001800)
# --- กำลังดึงข้อมูลสำหรับ Ticker: ABT (CIK: 0000001800) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\ABT_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\ABT_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\ABT_Cash_Flow_Statement_annual.csv
#
# (39/9691) บริษัท: MCD (CIK: 0000063908)
# --- กำลังดึงข้อมูลสำหรับ Ticker: MCD (CIK: 0000063908) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\MCD_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\MCD_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\MCD_Cash_Flow_Statement_annual.csv
#
# (40/9691) บริษัท: PLTR (CIK: 0001321655)
# --- กำลังดึงข้อมูลสำหรับ Ticker: PLTR (CIK: 0001321655) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\PLTR_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\PLTR_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\PLTR_Cash_Flow_Statement_annual.csv
#
# (41/9691) บริษัท: IBM (CIK: 0000051143)
# --- กำลังดึงข้อมูลสำหรับ Ticker: IBM (CIK: 0000051143) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\IBM_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\IBM_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\IBM_Cash_Flow_Statement_annual.csv
#
# (42/9691) บริษัท: CSCO (CIK: 0000858877)
# --- กำลังดึงข้อมูลสำหรับ Ticker: CSCO (CIK: 0000858877) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\CSCO_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\CSCO_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\CSCO_Cash_Flow_Statement_annual.csv
#
# (43/9691) บริษัท: NVS (CIK: 0001114448)
# --- กำลังดึงข้อมูลสำหรับ Ticker: NVS (CIK: 0001114448) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\NVS_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\NVS_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\NVS_Cash_Flow_Statement_annual.csv
#
# (44/9691) บริษัท: LIN (CIK: 0001707925)
# --- กำลังดึงข้อมูลสำหรับ Ticker: LIN (CIK: 0001707925) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\LIN_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\LIN_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\LIN_Cash_Flow_Statement_annual.csv
#
# (45/9691) บริษัท: WFC (CIK: 0000072971)
# --- กำลังดึงข้อมูลสำหรับ Ticker: WFC (CIK: 0000072971) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\WFC_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\WFC_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\WFC_Cash_Flow_Statement_annual.csv
#
# (46/9691) บริษัท: AZN (CIK: 0000901832)
# --- กำลังดึงข้อมูลสำหรับ Ticker: AZN (CIK: 0000901832) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\AZN_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\AZN_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\AZN_Cash_Flow_Statement_annual.csv
#
# (47/9691) บริษัท: GE (CIK: 0000040545)
# --- กำลังดึงข้อมูลสำหรับ Ticker: GE (CIK: 0000040545) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\GE_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\GE_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\GE_Cash_Flow_Statement_annual.csv
#
# (48/9691) บริษัท: T (CIK: 0000732717)
# --- กำลังดึงข้อมูลสำหรับ Ticker: T (CIK: 0000732717) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\T_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\T_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\T_Cash_Flow_Statement_annual.csv
#
# (49/9691) บริษัท: MRK (CIK: 0000310158)
# --- กำลังดึงข้อมูลสำหรับ Ticker: MRK (CIK: 0000310158) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\MRK_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\MRK_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\MRK_Cash_Flow_Statement_annual.csv
#
# (50/9691) บริษัท: PEP (CIK: 0000077476)
# --- กำลังดึงข้อมูลสำหรับ Ticker: PEP (CIK: 0000077476) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\PEP_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\PEP_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\PEP_Cash_Flow_Statement_annual.csv
#
# (51/9691) บริษัท: SHEL (CIK: 0001306965)
# --- กำลังดึงข้อมูลสำหรับ Ticker: SHEL (CIK: 0001306965) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\SHEL_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\SHEL_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\SHEL_Cash_Flow_Statement_annual.csv
#
# (52/9691) บริษัท: HDB (CIK: 0001144967)
# --- กำลังดึงข้อมูลสำหรับ Ticker: HDB (CIK: 0001144967) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\HDB_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\HDB_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\HDB_Cash_Flow_Statement_annual.csv
#
# (53/9691) บริษัท: HSBC (CIK: 0001089113)
# --- กำลังดึงข้อมูลสำหรับ Ticker: HSBC (CIK: 0001089113) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\HSBC_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\HSBC_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\HSBC_Cash_Flow_Statement_annual.csv
#
# (54/9691) บริษัท: VZ (CIK: 0000732712)
# --- กำลังดึงข้อมูลสำหรับ Ticker: VZ (CIK: 0000732712) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\VZ_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\VZ_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\VZ_Cash_Flow_Statement_annual.csv
#
# (55/9691) บริษัท: FMX (CIK: 0001061736)
# --- กำลังดึงข้อมูลสำหรับ Ticker: FMX (CIK: 0001061736) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\FMX_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\FMX_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\FMX_Cash_Flow_Statement_annual.csv
#
# (56/9691) บริษัท: AXP (CIK: 0000004962)
# --- กำลังดึงข้อมูลสำหรับ Ticker: AXP (CIK: 0000004962) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\AXP_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\AXP_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\AXP_Cash_Flow_Statement_annual.csv
#
# (57/9691) บริษัท: MS (CIK: 0000895421)
# --- กำลังดึงข้อมูลสำหรับ Ticker: MS (CIK: 0000895421) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\MS_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\MS_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\MS_Cash_Flow_Statement_annual.csv
#
# (58/9691) บริษัท: ACN (CIK: 0001467373)
# --- กำลังดึงข้อมูลสำหรับ Ticker: ACN (CIK: 0001467373) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\ACN_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\ACN_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\ACN_Cash_Flow_Statement_annual.csv
#
# (59/9691) บริษัท: ISRG (CIK: 0001035267)
# --- กำลังดึงข้อมูลสำหรับ Ticker: ISRG (CIK: 0001035267) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\ISRG_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\ISRG_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\ISRG_Cash_Flow_Statement_annual.csv
#
# (60/9691) บริษัท: QQQ (CIK: 0001067839)
# --- กำลังดึงข้อมูลสำหรับ Ticker: QQQ (CIK: 0001067839) ---
#   [ไม่พบข้อมูล] ไม่ได้รับข้อมูล Income_Statement หรือรูปแบบไม่ถูกต้อง
#   [ไม่พบข้อมูล] ไม่ได้รับข้อมูล Balance_Sheet หรือรูปแบบไม่ถูกต้อง
#   [ไม่พบข้อมูล] ไม่ได้รับข้อมูล Cash_Flow_Statement หรือรูปแบบไม่ถูกต้อง
#
# (61/9691) บริษัท: IDEXY (CIK: 0001438656)
# --- กำลังดึงข้อมูลสำหรับ Ticker: IDEXY (CIK: 0001438656) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\IDEXY_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\IDEXY_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\IDEXY_Cash_Flow_Statement_annual.csv
#
# (62/9691) บริษัท: INTU (CIK: 0000896878)
# --- กำลังดึงข้อมูลสำหรับ Ticker: INTU (CIK: 0000896878) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\INTU_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\INTU_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\INTU_Cash_Flow_Statement_annual.csv
#
# (63/9691) บริษัท: RY (CIK: 0001000275)
# --- กำลังดึงข้อมูลสำหรับ Ticker: RY (CIK: 0001000275) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\RY_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\RY_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\RY_Cash_Flow_Statement_annual.csv
#
# (64/9691) บริษัท: TMO (CIK: 0000097745)
# --- กำลังดึงข้อมูลสำหรับ Ticker: TMO (CIK: 0000097745) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\TMO_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\TMO_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\TMO_Cash_Flow_Statement_annual.csv
#
# (65/9691) บริษัท: BX (CIK: 0001393818)
# --- กำลังดึงข้อมูลสำหรับ Ticker: BX (CIK: 0001393818) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\BX_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\BX_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\BX_Cash_Flow_Statement_annual.csv
#
# (66/9691) บริษัท: GS (CIK: 0000886982)
# --- กำลังดึงข้อมูลสำหรับ Ticker: GS (CIK: 0000886982) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\GS_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\GS_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\GS_Cash_Flow_Statement_annual.csv
#
# (67/9691) บริษัท: NOW (CIK: 0001373715)
# --- กำลังดึงข้อมูลสำหรับ Ticker: NOW (CIK: 0001373715) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\NOW_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\NOW_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\NOW_Cash_Flow_Statement_annual.csv
#
# (68/9691) บริษัท: UL (CIK: 0000217410)
# --- กำลังดึงข้อมูลสำหรับ Ticker: UL (CIK: 0000217410) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\UL_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\UL_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\UL_Cash_Flow_Statement_annual.csv
#
# (69/9691) บริษัท: UBER (CIK: 0001543151)
# --- กำลังดึงข้อมูลสำหรับ Ticker: UBER (CIK: 0001543151) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\UBER_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\UBER_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\UBER_Cash_Flow_Statement_annual.csv
#
# (70/9691) บริษัท: PGR (CIK: 0000080661)
# --- กำลังดึงข้อมูลสำหรับ Ticker: PGR (CIK: 0000080661) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\PGR_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\PGR_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\PGR_Cash_Flow_Statement_annual.csv
#
# (71/9691) บริษัท: DIS (CIK: 0001744489)
# --- กำลังดึงข้อมูลสำหรับ Ticker: DIS (CIK: 0001744489) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\DIS_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\DIS_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\DIS_Cash_Flow_Statement_annual.csv
#
# (72/9691) บริษัท: RTX (CIK: 0000101829)
# --- กำลังดึงข้อมูลสำหรับ Ticker: RTX (CIK: 0000101829) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\RTX_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\RTX_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\RTX_Cash_Flow_Statement_annual.csv
#
# (73/9691) บริษัท: BKNG (CIK: 0001075531)
# --- กำลังดึงข้อมูลสำหรับ Ticker: BKNG (CIK: 0001075531) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\BKNG_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\BKNG_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\BKNG_Cash_Flow_Statement_annual.csv
#
# (74/9691) บริษัท: QCOM (CIK: 0000804328)
# --- กำลังดึงข้อมูลสำหรับ Ticker: QCOM (CIK: 0000804328) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\QCOM_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\QCOM_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\QCOM_Cash_Flow_Statement_annual.csv
#
# (75/9691) บริษัท: ADBE (CIK: 0000796343)
# --- กำลังดึงข้อมูลสำหรับ Ticker: ADBE (CIK: 0000796343) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\ADBE_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\ADBE_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\ADBE_Cash_Flow_Statement_annual.csv
#
# (76/9691) บริษัท: AMGN (CIK: 0000318154)
# --- กำลังดึงข้อมูลสำหรับ Ticker: AMGN (CIK: 0000318154) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\AMGN_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\AMGN_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\AMGN_Cash_Flow_Statement_annual.csv
#
# (77/9691) บริษัท: SONY (CIK: 0000313838)
# --- กำลังดึงข้อมูลสำหรับ Ticker: SONY (CIK: 0000313838) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\SONY_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\SONY_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\SONY_Cash_Flow_Statement_annual.csv
#
# (78/9691) บริษัท: SPGI (CIK: 0000064040)
# --- กำลังดึงข้อมูลสำหรับ Ticker: SPGI (CIK: 0000064040) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\SPGI_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\SPGI_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\SPGI_Cash_Flow_Statement_annual.csv
#
# (79/9691) บริษัท: TJX (CIK: 0000109198)
# --- กำลังดึงข้อมูลสำหรับ Ticker: TJX (CIK: 0000109198) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\TJX_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\TJX_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\TJX_Cash_Flow_Statement_annual.csv
#
# (80/9691) บริษัท: CAT (CIK: 0000018230)
# --- กำลังดึงข้อมูลสำหรับ Ticker: CAT (CIK: 0000018230) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\CAT_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\CAT_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\CAT_Cash_Flow_Statement_annual.csv
#
# (81/9691) บริษัท: BSX (CIK: 0000885725)
# --- กำลังดึงข้อมูลสำหรับ Ticker: BSX (CIK: 0000885725) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\BSX_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\BSX_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\BSX_Cash_Flow_Statement_annual.csv
#
# (82/9691) บริษัท: AMD (CIK: 0000002488)
# --- กำลังดึงข้อมูลสำหรับ Ticker: AMD (CIK: 0000002488) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\AMD_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\AMD_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\AMD_Cash_Flow_Statement_annual.csv
#
# (83/9691) บริษัท: BLK (CIK: 0002012383)
# --- กำลังดึงข้อมูลสำหรับ Ticker: BLK (CIK: 0002012383) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\BLK_Income_Statement_annual.csv
#   [สำเร็จ] บันทึก Balance_Sheet -> downloaded_csvs_api\BLK_Balance_Sheet_annual.csv
#   [สำเร็จ] บันทึก Cash_Flow_Statement -> downloaded_csvs_api\BLK_Cash_Flow_Statement_annual.csv
#
# (84/9691) บริษัท: SCHW (CIK: 0000316709)
# --- กำลังดึงข้อมูลสำหรับ Ticker: SCHW (CIK: 0000316709) ---
#   [สำเร็จ] บันทึก Income_Statement -> downloaded_csvs_api\SCHW_Income_Statement_annual.csv
#   [HTTP Error] Balance_Sheet (429): 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/balance-sheet-statement/SCHW?period=annual&limit=10&apikey=TTBEw02NHIVS6EbcDiOOQd5rewsoQCoN
#     Details: {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
#     !!! อาจถึงขีดจำกัดการเรียก API (Rate Limit) กำลังรอสักครู่...
#   [HTTP Error] Cash_Flow_Statement (429): 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/cash-flow-statement/SCHW?period=annual&limit=10&apikey=TTBEw02NHIVS6EbcDiOOQd5rewsoQCoN
#     Details: {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
#     !!! อาจถึงขีดจำกัดการเรียก API (Rate Limit) กำลังรอสักครู่...
#
# (85/9691) บริษัท: DHR (CIK: 0000313616)
# --- กำลังดึงข้อมูลสำหรับ Ticker: DHR (CIK: 0000313616) ---
#   [HTTP Error] Income_Statement (429): 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/income-statement/DHR?period=annual&limit=10&apikey=TTBEw02NHIVS6EbcDiOOQd5rewsoQCoN
#     Details: {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
#     !!! อาจถึงขีดจำกัดการเรียก API (Rate Limit) กำลังรอสักครู่...
#   [HTTP Error] Balance_Sheet (429): 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/balance-sheet-statement/DHR?period=annual&limit=10&apikey=TTBEw02NHIVS6EbcDiOOQd5rewsoQCoN
#     Details: {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
#     !!! อาจถึงขีดจำกัดการเรียก API (Rate Limit) กำลังรอสักครู่...
#   [HTTP Error] Cash_Flow_Statement (429): 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/cash-flow-statement/DHR?period=annual&limit=10&apikey=TTBEw02NHIVS6EbcDiOOQd5rewsoQCoN
#     Details: {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
#     !!! อาจถึงขีดจำกัดการเรียก API (Rate Limit) กำลังรอสักครู่...
#
# (86/9691) บริษัท: NEE (CIK: 0000753308)
# --- กำลังดึงข้อมูลสำหรับ Ticker: NEE (CIK: 0000753308) ---
#   [HTTP Error] Income_Statement (429): 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/income-statement/NEE?period=annual&limit=10&apikey=TTBEw02NHIVS6EbcDiOOQd5rewsoQCoN
#     Details: {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
#     !!! อาจถึงขีดจำกัดการเรียก API (Rate Limit) กำลังรอสักครู่...
#   [HTTP Error] Balance_Sheet (429): 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/balance-sheet-statement/NEE?period=annual&limit=10&apikey=TTBEw02NHIVS6EbcDiOOQd5rewsoQCoN
#     Details: {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
#     !!! อาจถึงขีดจำกัดการเรียก API (Rate Limit) กำลังรอสักครู่...
#   [HTTP Error] Cash_Flow_Statement (429): 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/cash-flow-statement/NEE?period=annual&limit=10&apikey=TTBEw02NHIVS6EbcDiOOQd5rewsoQCoN
#     Details: {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
#     !!! อาจถึงขีดจำกัดการเรียก API (Rate Limit) กำลังรอสักครู่...
#
# (87/9691) บริษัท: MUFG (CIK: 0000067088)
# --- กำลังดึงข้อมูลสำหรับ Ticker: MUFG (CIK: 0000067088) ---
#   [HTTP Error] Income_Statement (429): 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/income-statement/MUFG?period=annual&limit=10&apikey=TTBEw02NHIVS6EbcDiOOQd5rewsoQCoN
#     Details: {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
#     !!! อาจถึงขีดจำกัดการเรียก API (Rate Limit) กำลังรอสักครู่...
#   [HTTP Error] Balance_Sheet (429): 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/balance-sheet-statement/MUFG?period=annual&limit=10&apikey=TTBEw02NHIVS6EbcDiOOQd5rewsoQCoN
#     Details: {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
#     !!! อาจถึงขีดจำกัดการเรียก API (Rate Limit) กำลังรอสักครู่...
#   [HTTP Error] Cash_Flow_Statement (429): 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/cash-flow-statement/MUFG?period=annual&limit=10&apikey=TTBEw02NHIVS6EbcDiOOQd5rewsoQCoN
#     Details: {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
#     !!! อาจถึงขีดจำกัดการเรียก API (Rate Limit) กำลังรอสักครู่...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 134, in download_financial_statements_api(ticker, cik, api_key)
#     133 response = requests.get(url, params=params, headers=headers, timeout=30) # เพิ่ม timeout
# --> 134 response.raise_for_status()  # เช็ค HTTP status code (ถ้าไม่ใช่ 2xx จะเกิด exception)
#     136 data = response.json() # แปลง JSON response เป็น Python object
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/cash-flow-statement/MUFG?period=annual&limit=10&apikey=TTBEw02NHIVS6EbcDiOOQd5rewsoQCoN
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 239
#     236     ticker = row['ticker']
#     238     print(f"\n({current_index}/{total_companies}) บริษัท: {ticker} (CIK: {cik})")
# --> 239     download_financial_statements_api(ticker, cik, FMP_API_KEY)
#     241     # อาจเพิ่มการหน่วงเวลาระหว่างบริษัท หากเจอปัญหา Rate Limit บ่อยๆ
#     242     # time.sleep(2) # รอ 2 วินาทีก่อนทำบริษัทถัดไป
#     244 print("\n===== การดำเนินการดาวน์โหลด Financial Statements ผ่าน API เสร็จสิ้น =====")
#
# Cell In[1], line 177, in download_financial_statements_api(ticker, cik, api_key)
#     175      if e.response.status_code == 429:
#     176          print("    !!! อาจถึงขีดจำกัดการเรียก API (Rate Limit) กำลังรอสักครู่...")
# --> 177          time.sleep(10) # รอ 10 วินาทีถ้าเจอ Rate Limit
#     178 except requests.exceptions.Timeout:
#     179     print(f"  [Timeout Error] {name}: การร้องขอหมดเวลา")
#
# KeyboardInterrupt:
